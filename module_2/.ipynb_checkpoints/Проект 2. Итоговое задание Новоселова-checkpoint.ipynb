# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations
from scipy.stats import ttest_ind

pd.set_option('display.max_rows', 50) 
pd.set_option('display.max_columns', 50)

# %%
math = pd.read_csv('stud_math.csv')

# %% [markdown]
# # Задача
# Вас пригласили поучаствовать в одном из проектов UNICEF — международного подразделения ООН, чья миссия состоит в повышении уровня благополучия детей по всему миру.
#
# Суть проекта — отследить влияние условий жизни учащихся в возрасте от 15 до 22 лет на их успеваемость по математике, чтобы на ранней стадии выявлять студентов, находящихся в группе риска.
#
# И сделать это можно с помощью модели, которая предсказывала бы результаты госэкзамена по математике для каждого ученика школы (вот она, сила ML!). Чтобы определиться с параметрами будущей модели, проведите разведывательный анализ данных и составьте отчёт по его результатам.

# %% [markdown]
# ##### Первичный отсмотр данных

# %%
display(math.head(10))
math.info()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob     Fjob  \
# 0     GP   F   18       U     NaN       A   4.0   4.0   at_home  teacher
# 1     GP   F   17       U     GT3     NaN   1.0   1.0   at_home    other
# 2     GP   F   15       U     LE3       T   1.0   1.0   at_home    other
# 3     GP   F   15       U     GT3       T   4.0   2.0    health      NaN
# 4     GP   F   16       U     GT3       T   3.0   3.0     other    other
# 5     GP   M   16       U     LE3       T   4.0   3.0  services    other
# 6     GP   M   16     NaN     LE3       T   2.0   2.0     other    other
# 7     GP   F   17       U     GT3       A   4.0   4.0     other  teacher
# 8     GP   M   15       U     LE3       A   3.0   2.0  services    other
# 9     GP   M   15       U     NaN     NaN   3.0   4.0     other    other
#
#        reason guardian  traveltime  studytime  failures schoolsup famsup paid  \
# 0      course   mother         2.0        2.0       0.0       yes     no   no
# ...

# %% [markdown]
# ##### Теперь рассмотрим все столбцы по отдельности.

# %% [markdown]
# # school
# аббревиатура школы, в которой учится ученик

# %%
math.school.unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
#Вряд ли он пригодится для дальнейшего анализа, удалим его.
math.drop(['school'], inplace = True, axis = 1)

# %% [markdown]
# # address

# %%
#Аналогично со school
math.drop(['address'], inplace = True, axis = 1)

# %% [markdown]
# # sex

# %%
math.sex.unique()
#Столбец заполнен правильно без посторонних значений
# Out:
# array(['F', 'M'], dtype=object)

# %% [markdown]
# # age

# %%
math.age.unique()
#Столбец заполнен правильно без посторонних значений
# Out:
# array([18, 17, 15, 16, 19, 22, 20, 21], dtype=int64)

# %% [markdown]
# # famsize
# размер семьи('LE3' <= 3, 'GT3' >3)

# %%
math.famsize.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# GT3    261
# LE3    107
# Name: famsize, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.famsize = math.famsize.fillna(value='GT3', limit=1)
math.famsize = math.famsize.interpolate(method='pad', limit=2)

# %% [markdown]
# # Pstatus
# статус совместного жилья родителей ('T' - живут вместе 'A' - раздельно)

# %%
math.Pstatus.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# T    314
# A     36
# Name: Pstatus, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.Pstatus = math.Pstatus.interpolate(method='pad', limit=2)

# %% [markdown]
# # Medu
# образование матери (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее)

# %%
math.Medu.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# 4.0    131
# 2.0    102
# 3.0     97
# 1.0     59
# 0.0      3
# Name: Medu, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.Medu = math.Medu.interpolate(method='pad', limit=2)

# %% [markdown]
# # Fedu
# образование отца (0 - нет, 1 - 4 класса, 2 - 5-9 классы, 3 - среднее специальное или 11 классов, 4 - высшее)

# %%
math.Fedu.value_counts()
#Присутствует одно постороннее значение
# Out:
# 2.0     106
# 3.0      96
# 4.0      88
# 1.0      78
# 0.0       2
# 40.0      1
# Name: Fedu, dtype: int64

# %%
#Напишем функцию, чтобы заменить его
def replace_Fedu(item):
    if item == 40.0 :
        return 4.0
    else:
        return item
math['Fedu'] = math.Fedu.apply(replace_Fedu)

# %%
#Заполним пропуски в данных случайными значениями
math.Fedu = math.Fedu.interpolate(method='pad', limit=2)

# %%
math.Fedu.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# 2.0    112
# 3.0    105
# 4.0     93
# 1.0     83
# 0.0      2
# Name: Fedu, dtype: int64

# %% [markdown]
# # Mjob
# работа матери ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое)

# %%
math.Mjob.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# other       133
# services     98
# at_home      58
# teacher      55
# health       32
# Name: Mjob, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.Mjob = math.Mjob.interpolate(method='pad', limit=2)

# %% [markdown]
# # Fjob
# работа отца ('teacher' - учитель, 'health' - сфера здравоохранения, 'services' - гос служба, 'at_home' - не работает, 'other' - другое)

# %%
math.Fjob.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# other       197
# services    102
# teacher      29
# at_home      16
# health       15
# Name: Fjob, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.Fjob = math.Fjob.interpolate(method='pad', limit=2)

# %% [markdown]
# # reason
# причина выбора школы ('home' - близость к дому, 'reputation' - репутация школы, 'course' - образовательная программа, 'other' - другое)

# %%
math.reason.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# course        137
# home          104
# reputation    103
# other          34
# Name: reason, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.reason = math.reason.interpolate(method='pad', limit=2)

# %% [markdown]
# # guardian
# опекун ('mother' - мать, 'father' - отец, 'other' - другое)

# %%
math.guardian.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# mother    250
# father     86
# other      28
# Name: guardian, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.guardian = math.guardian.interpolate(method='pad', limit=2)

# %% [markdown]
# # traveltime
# время в пути до школы (1 - <15 мин., 2 - 15-30 мин., 3 - 30-60 мин., 4 - >60 мин.)

# %%
math.traveltime.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# 1.0    242
# 2.0     96
# 3.0     22
# 4.0      7
# Name: traveltime, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.traveltime = math.traveltime.interpolate(method='pad', limit=2)

# %% [markdown]
# # studytime
# время на учёбу помимо школы в неделю (1 - <2 часов, 2 - 2-5 часов, 3 - 5-10 часов, 4 - >10 часов)

# %%
math.studytime.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# 2.0    194
# 1.0    103
# 3.0     64
# 4.0     27
# Name: studytime, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.studytime = math.studytime.interpolate(method='pad', limit=2)

# %% [markdown]
# # failures
# количество внеучебных неудач (n, если 1<=n<=3, иначе 0)

# %%
math.failures.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# 0.0    293
# 1.0     49
# 2.0     16
# 3.0     15
# Name: failures, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.failures = math.failures.interpolate(method='pad', limit=2)

# %% [markdown]
# # schoolsup
# дополнительная образовательная поддержка (yes или no)

# %%
math.schoolsup.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# no     335
# yes     51
# Name: schoolsup, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.schoolsup = math.schoolsup.interpolate(method='pad', limit=2)

# %% [markdown]
# # famsup
# семейная образовательная поддержка (yes или no)

# %%
math.famsup.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# yes    219
# no     137
# Name: famsup, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.famsup = math.famsup.interpolate(method='pad', limit=2)

# %% [markdown]
# # paid
# дополнительные платные занятия по математике (yes или no)

# %%
math.paid.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# no     200
# yes    155
# Name: paid, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.paid = math.paid.interpolate(method='pad', limit=2)

# %% [markdown]
# # activities
# дополнительные внеучебные занятия (yes или no)

# %%
math.activities.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# yes    195
# no     186
# Name: activities, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.activities = math.activities.interpolate(method='pad', limit=2)

# %% [markdown]
# # nursery
# посещал детский сад (yes или no)

# %%
math.nursery.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# yes    300
# no      79
# Name: nursery, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.nursery = math.nursery.interpolate(method='pad', limit=2)

# %% [markdown]
# # studytime, granular

# %%
math['studytime, granular'].value_counts()
#В описании данных нет никакой информации об этом столбце
# Out:
# -6.0     194
# -3.0     103
# -9.0      64
# -12.0     27
# Name: studytime, granular, dtype: int64

# %%
#Исходя из этого предположим, что он не нужен и удалим его
math.drop(['studytime, granular'], inplace = True, axis = 1)

# %% [markdown]
# # higher
# хочет получить высшее образование (yes или no)

# %%
math.higher.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# yes    356
# no      19
# Name: higher, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.higher = math.higher.interpolate(method='pad', limit=2)

# %% [markdown]
# # internet
# наличие интернета дома (yes или no)

# %%
math.internet.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# yes    305
# no      56
# Name: internet, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.internet = math.internet.interpolate(method='pad', limit=2)

# %% [markdown]
# # romantic
# в романтических отношениях (yes или no)

# %%
math.romantic.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# no     240
# yes    124
# Name: romantic, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.romantic = math.romantic.interpolate(method='pad', limit=2)

# %% [markdown]
# # famrel
# семейные отношения (от 1 - очень плохо до 5 - очень хорошо)

# %%
math.famrel.value_counts()
#Присутствует одно постороннее значение
# Out:
#  4.0    182
#  5.0     99
#  3.0     62
#  2.0     17
#  1.0      7
# -1.0      1
# Name: famrel, dtype: int64

# %%
#Напишем функцию, чтобы заменить его
def replace_famrel(item):
    if item == -1.0 :
        return 1.0
    else:
        return item
math['famrel'] = math.famrel.apply(replace_famrel)

# %%
#Заполним пропуски в данных случайными значениями
math.famrel = math.famrel.interpolate(method='pad', limit=2)

# %%
math.famrel.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# 4.0    192
# 5.0    109
# 3.0     68
# 2.0     17
# 1.0      8
# Name: famrel, dtype: int64

# %% [markdown]
# # freetime
# свободное время после школы (от 1 - очень мало до 5 - очень мого)

# %%
math.freetime.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# 3.0    153
# 4.0    112
# 2.0     63
# 5.0     38
# 1.0     18
# Name: freetime, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.freetime = math.freetime.interpolate(method='pad', limit=2)

# %% [markdown]
# # goout
# проведение времени с друзьями (от 1 - очень мало до 5 - очень много)

# %%
math.goout.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# 3.0    127
# 2.0    101
# 4.0     84
# 5.0     52
# 1.0     23
# Name: goout, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.goout = math.goout.interpolate(method='pad', limit=2)

# %% [markdown]
# # health
# текущее состояние здоровья (от 1 - очень плохо до 5 - очень хорошо)

# %%
math.health.value_counts()
#Столбец заполнен правильно без посторонних значений
# Out:
# 5.0    138
# 3.0     89
# 4.0     63
# 1.0     47
# 2.0     43
# Name: health, dtype: int64

# %%
#Заполним пропуски в данных случайными значениями
math.health = math.health.interpolate(method='pad', limit=2)

# %% [markdown]
# # absences
# количество пропущенных занятий

# %%
#Посмотрим какие значение содержит столбец
math.absences.value_counts()
# Out:
# 0.0      111
# 2.0       60
# 4.0       53
# 6.0       31
# 8.0       21
# 10.0      17
# 12.0      12
# 14.0      12
# 3.0        8
# 16.0       7
# 7.0        6
# 5.0        5
# 18.0       5
# 20.0       4
# 22.0       3
# 9.0        3
# 1.0        3
# 15.0       2
# 13.0       2
# 11.0       2
# 25.0       1
# 54.0       1
# 385.0      1
# 26.0       1
# 56.0       1
# 24.0       1
# 212.0      1
# 21.0       1
# 75.0       1
# 30.0       1
# 19.0       1
# 38.0       1
# 40.0       1
# 23.0       1
# 17.0       1
# 28.0       1
# Name: absences, dtype: int64

# %%
#Проверим распределение признака
math.absences.hist()
math.absences.describe()
# Out:
# count    383.000000
# mean       7.279373
# std       23.465197
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        8.000000
# max      385.000000
# Name: absences, dtype: float64

# %% [markdown]
# Кажется, в данных присутствуют выбросы, устраним их:

# %%
#Воспользуемся формулой интерквартильного расстояния тобы отфильтровать выбросы

median = math.absences.median()
IQR = math.absences.quantile(0.75) - math.absences.quantile(0.25)
perc25 = math.absences.quantile(0.25)
perc75 = math.absences.quantile(0.75)
print('25-й перцентиль: {},'.format(perc25), '75-й перцентиль: {},'.format(perc75)
      , "IQR: {}, ".format(IQR),"Границы выбросов: [{f}, {l}].".format(f=perc25 - 1.5*IQR, l=perc75 + 1.5*IQR))
math.absences.loc[math.absences.between(perc25 - 1.5*IQR, perc75 + 1.5*IQR)].hist(bins = 50, range = (0, 40), 
                                                                                             label = 'IQR')
plt.legend();
# Out:
# 25-й перцентиль: 0.0, 75-й перцентиль: 8.0, IQR: 8.0,  Границы выбросов: [-12.0, 20.0].

# %%
#Этот способ позволиn нам отобрать экстремально низкие и экстремально высокие оценки. Отфильтруем данные:
math.absences = math.absences[math.absences.between(perc25 - 1.5*IQR, perc75 + 1.5*IQR)]

# %%
#Заполним пропуски в данных средним значением переменной
mean_abs = round(math.absences.mean(), 0)
math.absences = math.absences.fillna(mean_abs)

# %%
#Еще раз проверим распределение признака
math.absences.hist()
math.absences.describe()
#Признак распределен нормально
# Out:
# count    395.000000
# mean       4.632911
# std        4.780399
# min        0.000000
# 25%        0.000000
# 50%        4.000000
# 75%        6.000000
# max       20.000000
# Name: absences, dtype: float64

# %% [markdown]
# # score
# баллы по госэкзамену по математике

# %%
#Посмотрим какие значение содержит столбец
math.score.value_counts()
# Out:
# 50.0     54
# 55.0     46
# 0.0      37
# 75.0     33
# 65.0     31
# 40.0     31
# 60.0     31
# 70.0     27
# 45.0     27
# 80.0     16
# 30.0     15
# 90.0     12
# 35.0      9
# 25.0      7
# 85.0      6
# 95.0      5
# 100.0     1
# 20.0      1
# Name: score, dtype: int64

# %%
#Проверим распределение признака
math.score.hist()
math.score.describe()
# Out:
# count    389.000000
# mean      52.262211
# std       22.919022
# min        0.000000
# 25%       40.000000
# 50%       55.000000
# 75%       70.000000
# max      100.000000
# Name: score, dtype: float64

# %% [markdown]
# Признак распределен нормально, на гистограмме видно, что некоторое количество учеников набрало на экзамене 0 баллов. Возможно, они не пришли на экзамен или попались на списывании, в результате чего их результаты были обнулены. Для того, чтобы не искажать целевую переменную оставим все как есть.

# %%
#Удалим строки, где пропущены значения score
math = math.dropna(subset=['score'])

# %%
#Еще раз посмотрим на данные
display(math.head(10))
math.info()
# Out:
#   sex  age famsize Pstatus  Medu  Fedu      Mjob     Fjob      reason  \
# 0   F   18     GT3       A   4.0   4.0   at_home  teacher      course
# 1   F   17     GT3       A   1.0   1.0   at_home    other      course
# 2   F   15     LE3       T   1.0   1.0   at_home    other       other
# 3   F   15     GT3       T   4.0   2.0    health    other        home
# 4   F   16     GT3       T   3.0   3.0     other    other        home
# 5   M   16     LE3       T   4.0   3.0  services    other  reputation
# 6   M   16     LE3       T   2.0   2.0     other    other        home
# 7   F   17     GT3       A   4.0   4.0     other  teacher        home
# 8   M   15     LE3       A   3.0   2.0  services    other        home
# 9   M   15     LE3       A   3.0   4.0     other    other        home
#
#   guardian  traveltime  studytime  failures schoolsup famsup paid activities  \
# 0   mother         2.0        2.0       0.0       yes     no   no         no
# ...

# %% [markdown]
# Мы сократили количество стоблцов до 27, устранили выбросы и заполнили пустые значения

# %% [markdown]
# # Корреляционный анализ количественных переменных

# %% [markdown]
# Выясним, какие столбцы коррелируют с баллами по госэкзамену по математике.
#
# Корреляции рассмотрим только для числовых столбцов.

# %%
sns.pairplot(math.select_dtypes(include=['number']), kind = 'reg')

# %%
#Используем для наглядности матрицу корреляций:
math.corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.146820 -0.159979    0.075061  -0.023547  0.219192
# Medu       -0.146820  1.000000  0.600307   -0.138637   0.082827 -0.236819
# Fedu       -0.159979  0.600307  1.000000   -0.115555  -0.009661 -0.255107
# traveltime  0.075061 -0.138637 -0.115555    1.000000  -0.088093  0.056299
# studytime  -0.023547  0.082827 -0.009661   -0.088093   1.000000 -0.184350
# failures    0.219192 -0.236819 -0.255107    0.056299  -0.184350  1.000000
# famrel      0.067390 -0.001320  0.007911   -0.019578   0.057145 -0.034403
# freetime    0.010472  0.046557 -0.006579   -0.019814  -0.118128  0.069934
# goout       0.121035  0.071668  0.028507    0.046309  -0.055944  0.085200
# health     -0.070696 -0.031053  0.065263   -0.028119  -0.058437  0.053642
# absences    0.151216  0.062924 -0.012227   -0.031294  -0.074323  0.069143
# score      -0.155726  0.212158  0.127863   -0.062511   0.114894 -0.334081
#
# ...

# %% [markdown]
# После детального рассмотрения таблицы, мы можем сделать вывод, что в основном переменные слабоскоррелированны друг с другом, наиболее существенное влияние на переменную score оказывает переменная failures.
# Отрицательная корреляция может говорить о том, что чем с меньшим количеством внеучебных неудач сталкивается ученик, тем выше может быть его оценка на госэкзамене по математике.

# %% [markdown]
# # Анализ номинативных переменных

# %% [markdown]
# Посмотрим, различаются ли распределения score в зависимости от значения номинативных переменных. Для этого воспользуемся графиком box-plot

# %%
def get_boxplot(column):
    fig, ax = plt.subplots(figsize = (14, 4))
    sns.boxplot(x=column, y='score', 
                data=math,
               ax=ax)
    plt.xticks(rotation=45)
    ax.set_title('Boxplot for ' + column)
    plt.show()

# %%
for col in ['sex', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']:
    get_boxplot(col)

# %% [markdown]
# По графикам похоже, что такие параметры, как Mjob, guardian, schoolsup, famsup, nursery, higher, romantic, internet могут влиять на оценку на госэкзамене по математике. Проверим, есть ли статистическая разница в распределении оценок по номинативным признакам, с помощью теста Стьюдента. Проверим нулевую гипотезу о том, что распределения оценок по различным параметрам неразличимы:

# %% [markdown]
# ## Тест Стьюдента

# %%
def get_stat_dif(column):
    cols = math.loc[:, column].value_counts().index[:10]
    combinations_all = list(combinations(cols, 2))
    for comb in combinations_all:
        if ttest_ind(math.loc[math.loc[:, column] == comb[0], 'score'], 
                        math.loc[math.loc[:, column] == comb[1], 'score']).pvalue \
            <= 0.05/len(combinations_all): # Учли поправку Бонферони
            print('Найдены статистически значимые различия для колонки', column)
            break

# %%
for col in ['sex', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']:
    get_stat_dif(col)
# Out:
# Найдены статистически значимые различия для колонки Mjob
# Найдены статистически значимые различия для колонки higher
# Найдены статистически значимые различия для колонки romantic

# %% [markdown]
# Как мы видим, серьёзно отличаются три параметра: Mjob,  higher и  romantic. Оставим эти переменные в датасете для дальнейшего построения модели. Итак, в нашем случае важные переменные, которые, возможно, оказывают влияние на оценку, это: Mjob,  higher,  romantic и failures.

# %%
math_for_model = math.loc[:, ['Mjob', 'higher', 'romantic', 'failures']]
math_for_model.head()
# Out:
#       Mjob higher romantic  failures
# 0  at_home    yes       no       0.0
# 1  at_home    yes       no       0.0
# 2  at_home    yes       no       3.0
# 3   health    yes      yes       0.0
# 4    other    yes       no       0.0

# %% [markdown]
# # Выводы

# %% [markdown]
# Итак, в результате EDA для анализа влияния условий жизни учащихся в возрасте от 15 до 22 лет на их успеваемость по математике были получены следующие выводы:
#
# 1. В данных достаточно мало пустых значений.
# 2. Выбросы найдены только в столбцах с количеством пропущенных занятий, образованием отца и семейными отношениями, что позволяет сделать вывод о том, что данные достаточно чистые.
# 3. Самые важные параметры, которые предлагается использовать в дальнейшем для построения модели, это Mjob, higher, romantic и failures.
